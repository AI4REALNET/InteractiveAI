# %%
import pandas
import json

# %%
from datetime import datetime, timedelta

# %%
######### Interdependant Events

event_payload11 = json.dumps({
#"criticality": "HIGH", #MEDIUM or LOW
                    "title": "Malaise Voyageurs, Dérangement d'installation, Gare de Poitiers",
                    "description": "Malaise Voyageurs au TGV AB001. Intervention des pompiers en gare de Poitiers. Au même moment, dérangement d'installation à Poitiers accès impossible. Heure de restitution prévisible: 12h00." ,
                    "data": {
                        #"simulation_name" : None,
                        "event_type": "PASSENGER", #INFRASTRUCTURE or IMPACT or HARDWARE
                        "id_train": "AB001",
                        "agent_id": "1",
                        #"delay": "5 hour",
                        #"proba": "0.4"
                    },
                    #"start_date": iso_date,
                    #"end_date": iso_date,
                    "use_case": "Railway"
}
)


event_payload12 = json.dumps({
#"criticality": "HIGH", #MEDIUM or LOW
                    "title": "Malaise Voyageurs, Dérangement d'installation, Gare de Poitiers",
                    "description": "Malaise Voyageurs au TGV AB001. Intervention des pompiers en gare de Poitiers. Au même moment, dérangement d'installation à Poitiers accès impossible. Heure de restitution prévisible: 12h00." ,
                    "data": {
                        #"simulation_name" : None,
                        "event_type": "PASSENGER", #INFRASTRUCTURE or IMPACT or HARDWARE
                        "id_train": "AB002",
                        "agent_id": "1",
                        #"delay": "5 hour",
                        #"proba": "0.4"
                    },
                    #"start_date": iso_date,
                    #"end_date": iso_date,
                    "use_case": "Railway"
}
)


event_payload13 = json.dumps({
#"criticality": "HIGH", #MEDIUM or LOW
                    "title": "Malaise Voyageurs, Dérangement d'installation, Gare de Poitiers",
                    "description": "Malaise Voyageurs au TGV AB001. Intervention des pompiers en gare de Poitiers. Au même moment, dérangement d'installation à Poitiers accès impossible. Heure de restitution prévisible: 12h00." ,
                    "data": {
                        #"simulation_name" : None,
                        "event_type": "PASSENGER", #INFRASTRUCTURE or IMPACT or HARDWARE
                        "id_train": "AB003",
                        "agent_id": "1",
                        #"delay": "5 hour",
                        #"proba": "0.4"
                    },
                    #"start_date": iso_date,
                    #"end_date": iso_date,
                    "use_case": "Railway"
}
)



event_payload14 = json.dumps({
#"criticality": "HIGH", #MEDIUM or LOW
                    "title": "Malaise Voyageurs, Dérangement d'installation, Gare de Poitiers",
                    "description": "Malaise Voyageurs au TGV AB001. Intervention des pompiers en gare de Poitiers. Au même moment, dérangement d'installation à Poitiers accès impossible. Heure de restitution prévisible: 12h00." ,
                    "data": {
                        #"simulation_name" : None,
                        "event_type": "PASSENGER", #INFRASTRUCTURE or IMPACT or HARDWARE
                        "id_train": "AB004",
                        "agent_id": "1",
                        #"delay": "5 hour",
                        #"proba": "0.4"
                    },
                    #"start_date": iso_date,
                    #"end_date": iso_date,
                    "use_case": "Railway"
}
)


event_payload15 = json.dumps({
#"criticality": "HIGH", #MEDIUM or LOW
                    "title": "Malaise Voyageurs, Dérangement d'installation, Gare de Poitiers",
                    "description": "Malaise Voyageurs au TGV AB001. Intervention des pompiers en gare de Poitiers. Au même moment, dérangement d'installation à Poitiers accès impossible. Heure de restitution prévisible: 12h00." ,
                    "data": {
                        #"simulation_name" : None,
                        "event_type": "PASSENGER", #INFRASTRUCTURE or IMPACT or HARDWARE
                        "id_train": "AB005",
                        "agent_id": "1",
                        #"delay": "5 hour",
                        #"proba": "0.4"
                    },
                    #"start_date": iso_date,
                    #"end_date": iso_date,
                    "use_case": "Railway"
}
)




######################## Common Context

context_payload1 = json.dumps({
"data": {
                "trains": [{ # peut mettre plusieurs trains
                        "id_train": "AB001",
                        "nb_passengers_onboard": "468",
                        "trajet" : "Paris/Bordeaux",
                        "arrets":"Poitiers/Bordeaux",
                        #"nb_passengers_connection": None,
                        #"latitude": latitude,
                        #"longitude": longitude,
                        #"speed": None,
                        "failure": "FALSE"
                },
                { # peut mettre plusieurs trains
                        "id_train": "AB002",
                        "nb_passengers_onboard": "647",
                        "trajet" : "Paris/Bordeaux",
                        "arrets":"St Pierre des Corps / Poitiers / Angoulême/ Bordeaux",
                        #"nb_passengers_connection": None,
                        #"latitude": latitude,
                        #"longitude": longitude,
                        #"speed": None,
                        "failure": "FALSE"
                },
                { # peut mettre plusieurs trains
                        "id_train": "AB003",
                        "nb_passengers_onboard": "232",
                        "trajet" : "Lille/Bordeaux",
                        "arrets":"St Pierre des Corps / Poitiers / Angoulême/ Bordeaux",
                        #"nb_passengers_connection": None,
                        #"latitude": latitude,
                        #"longitude": longitude,
                        #"speed": None,
                        "failure": "FALSE"
                },
                { # peut mettre plusieurs trains
                        "id_train": "AB004",
                        "nb_passengers_onboard": "615",
                        "trajet" : "Bordeaux/Paris",
                        "arrets":"Bordeaux /Angoulême/Poitiers",
                        #"nb_passengers_connection": None,
                        #"latitude": latitude,
                        #"longitude": longitude,
                        #"speed": None,
                        "failure": "FALSE"
                },
                { # peut mettre plusieurs trains
                        "id_train": "AB005",
                        "nb_passengers_onboard": "463",
                        "trajet" : "Bordeaux/Strasbourg",
                        "arrets":"Bordeaux /Angoulême/Poitiers/St Pierre des Corps",
                        #"nb_passengers_connection": None,
                        #"latitude": latitude,
                        #"longitude": longitude,
                        #"speed": None,
                        "failure": "FALSE"
                }
                ]
                #"list_of_target": None,
                #"direction_agents": None,
                #"position_agents": None,
            },
            #"date": iso_date,
            "use_case": "Railway",
}
)

# %%
event_payload11 = json.dumps({
#"criticality": "HIGH", #MEDIUM or LOW
                    "title": "Malaise Voyageurs, Dérangement d'installation, Gare de Poitiers",
                    "description": "Malaise Voyageurs au TGV AB001. Intervention des pompiers en gare de Poitiers. Au même moment, dérangement d'installation à Poitiers accès impossible. Heure de restitution prévisible: 12h00." ,
                    "data": {
                        #"simulation_name" : None,
                        "event_type": "PASSENGER", #INFRASTRUCTURE or IMPACT or HARDWARE
                        "id_train": "AB001",
                        "agent_id": "1",
                        #"delay": "5 hour",
                        #"proba": "0.4"
                    },
                    #"start_date": iso_date,
                    #"end_date": iso_date,
                    "use_case": "Railway"
}
)


context_payload1 = json.dumps({
"data": {
                "trains": { # peut mettre plusieurs trains
                        "id_train": "AB001",
                        "nb_passengers_onboard": "468",
                        "trajet" : "Paris/Bordeaux",
                        "arrets":"Poitiers/Bordeaux",
                        #"nb_passengers_connection": None,
                        #"latitude": latitude,
                        #"longitude": longitude,
                        #"speed": None,
                        "failure": "FALSE"
                }
        }       
}         
)

# %%
######### Interdependant Events

event_payload21 = json.dumps({
#"criticality": "HIGH", #MEDIUM or LOW
                    "title": "Caténaire arrachée ",
                    "description": "Le TGV CD001 a arraché la caténaire au niveau du poste 60 de Pliboux sur la LGV SEA. La voie est contigüe n'est pas accessible. Les trains sont détournés par la ligne classique entre Poitiers et  Angoulême. Heure de restitution prévisible d'une voie : 23h00.",
                    "data": {
                        #"simulation_name" : None,
                        "event_type": "HARDWARE", #INFRASTRUCTURE or IMPACT or HARDWARE
                        "id_train": "AB001",
                        "agent_id": "1",
                        #"delay": "5 hour",
                        #"proba": "0.4"
                    },
                    #"start_date": iso_date,
                    #"end_date": iso_date,
                    "use_case": "Railway"
}
)


event_payload22 = json.dumps({
#"criticality": "HIGH", #MEDIUM or LOW
                    "title": "Caténaire arrachée ",
                    "description": "Le TGV CD001 a arraché la caténaire au niveau du poste 60 de Pliboux sur la LGV SEA. La voie est contigüe n'est pas accessible. Les trains sont détournés par la ligne classique entre Poitiers et  Angoulême. Heure de restitution prévisible d'une voie : 23h00.",
                    "data": {
                        #"simulation_name" : None,
                        "event_type": "HARDWARE", #INFRASTRUCTURE or IMPACT or HARDWARE
                        "id_train": "AB002",
                        "agent_id": "1",
                        #"delay": "5 hour",
                        #"proba": "0.4"
                    },
                    #"start_date": iso_date,
                    #"end_date": iso_date,
                    "use_case": "Railway"
}
)

event_payload23 = json.dumps({
#"criticality": "HIGH", #MEDIUM or LOW
                    "title": "Caténaire arrachée ",
                    "description": "Le TGV CD001 a arraché la caténaire au niveau du poste 60 de Pliboux sur la LGV SEA. La voie est contigüe n'est pas accessible. Les trains sont détournés par la ligne classique entre Poitiers et  Angoulême. Heure de restitution prévisible d'une voie : 23h00.",
                    "data": {
                        #"simulation_name" : None,
                        "event_type": "HARDWARE", #INFRASTRUCTURE or IMPACT or HARDWARE
                        "id_train": "AB003",
                        "agent_id": "1",
                        #"delay": "5 hour",
                        #"proba": "0.4"
                    },
                    #"start_date": iso_date,
                    #"end_date": iso_date,
                    "use_case": "Railway"
}
)

event_payload24 = json.dumps({
#"criticality": "HIGH", #MEDIUM or LOW
                    "title": "Caténaire arrachée ",
                    "description": "Le TGV CD001 a arraché la caténaire au niveau du poste 60 de Pliboux sur la LGV SEA. La voie est contigüe n'est pas accessible. Les trains sont détournés par la ligne classique entre Poitiers et  Angoulême. Heure de restitution prévisible d'une voie : 23h00.",
                    "data": {
                        #"simulation_name" : None,
                        "event_type": "HARDWARE", #INFRASTRUCTURE or IMPACT or HARDWARE
                        "id_train": "AB004",
                        "agent_id": "1",
                        #"delay": "5 hour",
                        #"proba": "0.4"
                    },
                    #"start_date": iso_date,
                    #"end_date": iso_date,
                    "use_case": "Railway"
}
)

event_payload25 = json.dumps({
#"criticality": "HIGH", #MEDIUM or LOW
                    "title": "Caténaire arrachée ",
                    "description": "Le TGV CD001 a arraché la caténaire au niveau du poste 60 de Pliboux sur la LGV SEA. La voie est contigüe n'est pas accessible. Les trains sont détournés par la ligne classique entre Poitiers et  Angoulême. Heure de restitution prévisible d'une voie : 23h00.",
                    "data": {
                        #"simulation_name" : None,
                        "event_type": "HARDWARE", #INFRASTRUCTURE or IMPACT or HARDWARE
                        "id_train": "AB005",
                        "agent_id": "1",
                        #"delay": "5 hour",
                        #"proba": "0.4"
                    },
                    #"start_date": iso_date,
                    #"end_date": iso_date,
                    "use_case": "Railway"
}
)

event_payload26 = json.dumps({
#"criticality": "HIGH", #MEDIUM or LOW
                    "title": "Caténaire arrachée ",
                    "description": "Le TGV CD001 a arraché la caténaire au niveau du poste 60 de Pliboux sur la LGV SEA. La voie est contigüe n'est pas accessible. Les trains sont détournés par la ligne classique entre Poitiers et  Angoulême. Heure de restitution prévisible d'une voie : 23h00.",
                    "data": {
                        #"simulation_name" : None,
                        "event_type": "HARDWARE", #INFRASTRUCTURE or IMPACT or HARDWARE
                        "id_train": "AB006",
                        "agent_id": "1",
                        #"delay": "5 hour",
                        #"proba": "0.4"
                    },
                    #"start_date": iso_date,
                    #"end_date": iso_date,
                    "use_case": "Railway"
}
)

event_payload27 = json.dumps({
#"criticality": "HIGH", #MEDIUM or LOW
                    "title": "Caténaire arrachée ",
                    "description": "Le TGV CD001 a arraché la caténaire au niveau du poste 60 de Pliboux sur la LGV SEA. La voie est contigüe n'est pas accessible. Les trains sont détournés par la ligne classique entre Poitiers et  Angoulême. Heure de restitution prévisible d'une voie : 23h00.",
                    "data": {
                        #"simulation_name" : None,
                        "event_type": "HARDWARE", #INFRASTRUCTURE or IMPACT or HARDWARE
                        "id_train": "AB007",
                        "agent_id": "1",
                        #"delay": "5 hour",
                        #"proba": "0.4"
                    },
                    #"start_date": iso_date,
                    #"end_date": iso_date,
                    "use_case": "Railway"
}
)

event_payload28 = json.dumps({
#"criticality": "HIGH", #MEDIUM or LOW
                    "title": "Caténaire arrachée ",
                    "description": "Le TGV CD001 a arraché la caténaire au niveau du poste 60 de Pliboux sur la LGV SEA. La voie est contigüe n'est pas accessible. Les trains sont détournés par la ligne classique entre Poitiers et  Angoulême. Heure de restitution prévisible d'une voie : 23h00.",
                    "data": {
                        #"simulation_name" : None,
                        "event_type": "HARDWARE", #INFRASTRUCTURE or IMPACT or HARDWARE
                        "id_train": "AB008",
                        "agent_id": "1",
                        #"delay": "5 hour",
                        #"proba": "0.4"
                    },
                    #"start_date": iso_date,
                    #"end_date": iso_date,
                    "use_case": "Railway"
}
)

event_payload29 = json.dumps({
#"criticality": "HIGH", #MEDIUM or LOW
                    "title": "Caténaire arrachée ",
                    "description": "Le TGV CD001 a arraché la caténaire au niveau du poste 60 de Pliboux sur la LGV SEA. La voie est contigüe n'est pas accessible. Les trains sont détournés par la ligne classique entre Poitiers et  Angoulême. Heure de restitution prévisible d'une voie : 23h00.",
                    "data": {
                        #"simulation_name" : None,
                        "event_type": "HARDWARE", #INFRASTRUCTURE or IMPACT or HARDWARE
                        "id_train": "AB009",
                        "agent_id": "1",
                        #"delay": "5 hour",
                        #"proba": "0.4"
                    },
                    #"start_date": iso_date,
                    #"end_date": iso_date,
                    "use_case": "Railway"
}
)

event_payload210 = json.dumps({
#"criticality": "HIGH", #MEDIUM or LOW
                    "title": "Caténaire arrachée ",
                    "description": "Le TGV CD001 a arraché la caténaire au niveau du poste 60 de Pliboux sur la LGV SEA. La voie est contigüe n'est pas accessible. Les trains sont détournés par la ligne classique entre Poitiers et  Angoulême. Heure de restitution prévisible d'une voie : 23h00.",
                    "data": {
                        #"simulation_name" : None,
                        "event_type": "HARDWARE", #INFRASTRUCTURE or IMPACT or HARDWARE
                        "id_train": "AB0010",
                        "agent_id": "1",
                        #"delay": "5 hour",
                        #"proba": "0.4"
                    },
                    #"start_date": iso_date,
                    #"end_date": iso_date,
                    "use_case": "Railway"
}
)



########### Commonn context

context_payload2 = json.dumps({
"data": {
                "trains": [{ # peut mettre plusieurs trains
                        "id_train": "AB001",
                        "nb_passengers_onboard": "459",
                        "trajet" : "Paris/Bordeaux",
                        "arrets":"Angoulême/Bordeaux",
                        #"nb_passengers_connection": None,
                        #"latitude": latitude,
                        #"longitude": longitude,
                        #"speed": None,
                        "failure": "FALSE"
                },
                { # peut mettre plusieurs trains
                        "id_train": "AB002",
                        "nb_passengers_onboard": "725",
                        "trajet" : "Hendaye/Paris",
                        "arrets":"Bordeaux",
                        #"nb_passengers_connection": None,
                        #"latitude": latitude,
                        #"longitude": longitude,
                        #"speed": None,
                        "failure": "FALSE"
                },
                { # peut mettre plusieurs trains
                        "id_train": "AB003",
                        "nb_passengers_onboard": "1082",
                        "trajet" : "Paris/Hendaye",
                        "arrets":"Bordeaux",
                        #"nb_passengers_connection": None,
                        #"latitude": latitude,
                        #"longitude": longitude,
                        #"speed": None,
                        "failure": "FALSE"
                },
                { # peut mettre plusieurs trains
                        "id_train": "AB004",
                        "nb_passengers_onboard": "264",
                        "trajet" : "Bordeaux/Paris",
                        "arrets":"Bordeaux / Angoulême/ Poitiers / St Pierre des Corps",
                        #"nb_passengers_connection": None,
                        #"latitude": latitude,
                        #"longitude": longitude,
                        #"speed": None,
                        "failure": "FALSE"
                },
                { # peut mettre plusieurs trains
                        "id_train": "AB005",
                        "nb_passengers_onboard": "544",
                        "trajet" : "Paris /Arcachon",
                        "arrets":"Bordeaux",
                        #"nb_passengers_connection": None,
                        #"latitude": latitude,
                        #"longitude": longitude,
                        #"speed": None,
                        "failure": "FALSE"
                },
                { # peut mettre plusieurs trains
                        "id_train": "AB006",
                        "nb_passengers_onboard": "173",
                        "trajet" : "Paris /Bordeaux",
                        "arrets":"Poitiers/Angoulême/Libourne/Bordeaux",
                        #"nb_passengers_connection": None,
                        #"latitude": latitude,
                        #"longitude": longitude,
                        #"speed": None,
                        "failure": "FALSE"
                },
                { # peut mettre plusieurs trains
                        "id_train": "AB007",
                        "nb_passengers_onboard": "711",
                        "trajet" : "Paris /Toulouse",
                        "arrets":"Angoulême / Bordeaux",
                        #"nb_passengers_connection": None,
                        #"latitude": latitude,
                        #"longitude": longitude,
                        #"speed": None,
                        "failure": "FALSE"
                },
                { # peut mettre plusieurs trains
                        "id_train": "AB008",
                        "nb_passengers_onboard": "835",
                        "trajet" : "Tarbes/Paris",
                        "arrets":"Bordeaux",
                        #"nb_passengers_connection": None,
                        #"latitude": latitude,
                        #"longitude": longitude,
                        #"speed": None,
                        "failure": "FALSE"
                },
                { # peut mettre plusieurs trains
                        "id_train": "AB009",
                        "nb_passengers_onboard": "524",
                        "trajet" : "Paris /Bordeaux",
                        "arrets":"St Pierre des Corps / Bordeaux ",
                        #"nb_passengers_connection": None,
                        #"latitude": latitude,
                        #"longitude": longitude,
                        #"speed": None,
                        "failure": "FALSE"
                },
                { # peut mettre plusieurs trains
                        "id_train": "AB0010",
                        "nb_passengers_onboard": "522",
                        "trajet" : "Paris /ATarbes",
                        "arrets":"Bordeaux",
                        #"nb_passengers_connection": None,
                        #"latitude": latitude,
                        #"longitude": longitude,
                        #"speed": None,
                        "failure": "FALSE"
                },
                ]
                #"list_of_target": None,
                #"direction_agents": None,
                #"position_agents": None,
            },
            #"date": iso_date,
            "use_case": "Railway",
}

# %%
event_payload21 = json.dumps({
#"criticality": "HIGH", #MEDIUM or LOW
                    "title": "Caténaire arrachée ",
                    "description": "Le TGV CD001 a arraché la caténaire au niveau du poste 60 de Pliboux sur la LGV SEA. La voie est contigüe n'est pas accessible. Les trains sont détournés par la ligne classique entre Poitiers et  Angoulême. Heure de restitution prévisible d'une voie : 23h00.",
                    "data": {
                        #"simulation_name" : None,
                        "event_type": "HARDWARE", #INFRASTRUCTURE or IMPACT or HARDWARE
                        "id_train": "AB001",
                        "agent_id": "1",
                        #"delay": "5 hour",
                        #"proba": "0.4"
                    },
                    #"start_date": iso_date,
                    #"end_date": iso_date,
                    "use_case": "Railway"
}
)


context_payload2 = json.dumps({
"data": {
                "trains": { # peut mettre plusieurs trains
                        "id_train": "AB001",
                        "nb_passengers_onboard": "459",
                        "trajet" : "Paris/Bordeaux",
                        "arrets":"Angoulême/Bordeaux",
                        #"nb_passengers_connection": None,
                        #"latitude": latitude,
                        #"longitude": longitude,
                        #"speed": None,
                        "failure": "FALSE"
                }
        }
}
)

# %%
######### Interdependant Events

event_payload31 = json.dumps({
#"criticality": "HIGH", #MEDIUM or LOW
                    "title": "Fuite de gaz de ville",
                    "description": "Fuite de gaz au niveau de Bassens. La plateforme ferroviaire se retrouve dans le périmètre de sécurité. Les autorités décident d'interdir la circulation. Heure de restitution prévisible : 19h00.",
                    "data": {
                        #"simulation_name" : None,
                        "event_type": "HARDWARE", #INFRASTRUCTURE or IMPACT or HARDWARE
                        "id_train": "EF004",
                        "agent_id": "1",
                        #"delay": "5 hour",
                        #"proba": "0.4"
                    },
                    #"start_date": iso_date,
                    #"end_date": iso_date,
                    "use_case": "Railway"
}
)


event_payload32 = json.dumps({
#"criticality": "HIGH", #MEDIUM or LOW
                    "title": "Fuite de gaz de ville",
                    "description": "Fuite de gaz au niveau de Bassens. La plateforme ferroviaire se retrouve dans le périmètre de sécurité. Les autorités décident d'interdir la circulation. Heure de restitution prévisible : 19h00.",
                    "data": {
                        #"simulation_name" : None,
                        "event_type": "HARDWARE", #INFRASTRUCTURE or IMPACT or HARDWARE
                        "id_train": "EF006",
                        "agent_id": "1",
                        #"delay": "5 hour",
                        #"proba": "0.4"
                    },
                    #"start_date": iso_date,
                    #"end_date": iso_date,
                    "use_case": "Railway"
}
)


event_payload33 = json.dumps({
#"criticality": "HIGH", #MEDIUM or LOW
                    "title": "Fuite de gaz de ville",
                    "description": "Fuite de gaz au niveau de Bassens. La plateforme ferroviaire se retrouve dans le périmètre de sécurité. Les autorités décident d'interdir la circulation. Heure de restitution prévisible : 19h00.",
                    "data": {
                        #"simulation_name" : None,
                        "event_type": "HARDWARE", #INFRASTRUCTURE or IMPACT or HARDWARE
                        "id_train": "8",
                        "agent_id": "1",
                        #"delay": "5 hour",
                        #"proba": "0.4"
                    },
                    #"start_date": iso_date,
                    #"end_date": iso_date,
                    "use_case": "Railway"
}
)




######################## Common Context

context_payload3 = json.dumps({
"data": {
                "trains": [{ # peut mettre plusieurs trains
                        "id_train": "EF004",
                        "nb_passengers_onboard": "348",
                        "trajet" : "Bordeaux / Paris",
                        "arrets":"Bordeaux / Libourne/ Angoulême / Poitiers / Chatellerault",
                        #"nb_passengers_connection": None,
                        #"latitude": latitude,
                        #"longitude": longitude,
                        #"speed": None,
                        "failure": "FALSE"
                },
                { # peut mettre plusieurs trains
                        "id_train": "EF006",
                        "nb_passengers_onboard": "502",
                        "trajet" : "Bordeaux / Tourcoing",
                        "arrets":"Bordeaux",
                        #"nb_passengers_connection": None,
                        #"latitude": latitude,
                        #"longitude": longitude,
                        #"speed": None,
                        "failure": "FALSE"
                },
                { # peut mettre plusieurs trains
                        "id_train": "EF008",
                        "nb_passengers_onboard": "891",
                        "trajet" : "Toulouse / Paris",
                        "arrets":"Bordeaux",
                        #"nb_passengers_connection": None,
                        #"latitude": latitude,
                        #"longitude": longitude,
                        #"speed": None,
                        "failure": "FALSE"
                }
                ]
                #"list_of_target": None,
                #"direction_agents": None,
                #"position_agents": None,
            },
            #"date": iso_date,
            "use_case": "Railway",
}
)

# %%
event_payload31 = json.dumps({
#"criticality": "HIGH", #MEDIUM or LOW
                    "title": "Fuite de gaz de ville",
                    "description": "Fuite de gaz au niveau de Bassens. La plateforme ferroviaire se retrouve dans le périmètre de sécurité. Les autorités décident d'interdir la circulation. Heure de restitution prévisible : 19h00.",
                    "data": {
                        #"simulation_name" : None,
                        "event_type": "INFRASTRUCTURE", #INFRASTRUCTURE or IMPACT or HARDWARE
                        "id_train": "EF004",
                        "agent_id": "1",
                        #"delay": "5 hour",
                        #"proba": "0.4"
                    },
                    #"start_date": iso_date,
                    #"end_date": iso_date,
                    "use_case": "Railway"
}
)

context_payload3 = json.dumps({
"data": {
                "trains": { # peut mettre plusieurs trains
                        "id_train": "EF004",
                        "nb_passengers_onboard": "348",
                        "trajet" : "Bordeaux / Paris",
                        "arrets":"Bordeaux / Libourne/ Angoulême / Poitiers / Chatellerault",
                        #"nb_passengers_connection": None,
                        #"latitude": latitude,
                        #"longitude": longitude,
                        #"speed": None,
                        "failure": "FALSE"
                }
        }
}
)

# %% [markdown]
# #### Reco json

# %%
{  "title": "Title displayed on each reco",
  "description": "Detailed description to help operator understand the proposed reco",
  "use_case": "Railway",
  "agent_type": "AI",
  "kpis": {
    "kpi1_name": "kpi1_value",
    "kpi2_name": "kpi2_value"}}

# %%
Reco11 = json.dumps({
"data": {
                "title": "Retenir en gare à St Pierre des Corps",
                "description" : "Retenir le train en gare à St Pierre des Corps jusqu' à la restitution des voies.",
                "use_case": "Railway",
                "agent_type": "AI",
                "kpis": {
                        "cost" : "78",
                        "nb_impacted_passengers" : "468",
                        "total_cost" : "32838",
                        "delay" : "1h30",
                        "best": "True",
                        }
                    
        }
}
)

Reco12 = json.dumps({
"data": {
                "title": "Retarder",
                "description" : "Retenir le train en pleine voie jusqu'à la restitution des voies. Mise en place de moyens pour la prise en charge des clients ",
                "use_case": "Railway",
                "agent_type": "AI",
                "kpis": {
                        "cost" : "87",
                        "nb_impacted_passengers" : "398",
                        "total_cost" : "34626",
                        "delay" : "1h30",
                        "best": "False",
                        }
                    
        }
}
)


Reco13 = json.dumps({
"data": {
                "title": "Modifier parcours",
                "description" : "Détournement des trains. Les clients à destination et au départ de Poitiers sont pris en charge.",
                "use_case": "Railway",
                "agent_type": "AI",
                "kpis": {
                        "cost" : "102",
                        "nb_impacted_passengers" : "350",
                        "total_cost" : "35700",
                        "delay" : "1h40",
                        "best": "False",
                        }
                    
        }
}
)


Reco14 = json.dumps({
"data": {
                "title": "Supprimer",
                "description" : "Suppression des trains. Les clients sont invités à reporter leur voyage.",
                "use_case": "Railway",
                "agent_type": "AI",
                "kpis": {
                        "cost" : "233",
                        "nb_impacted_passengers" : "468",
                        "total_cost" : "109044",
                        "delay" : "1h45",
                        "best": "False",
                        }
                    
        }
}
)

# %%
Reco21 = json.dumps({
"data": {
                "title": "Retenir en gare",
                "description" : "Retenir le train en gare de Poitiers jusqu' à la restitution des voies.",
                "use_case": "Railway",
                "agent_type": "AI",
                "kpis": {
                        "cost" : "123",
                        "nb_impacted_passengers" : "459",
                        "total_cost" : "56457",
                        "delay" : "1h05",
                        "best": "False",
                        }
                    
        }
}
)





Reco22 = json.dumps({
"data": {
                "title": "Retarder",
                "description" : "Retenir le train en pleine voie jusqu'à la restitution des voies. Mise en place de moyens pour la prise en charge des clients ",
                "use_case": "Railway",
                "agent_type": "AI",
                "kpis": {
                        "cost" : "129",
                        "nb_impacted_passengers" : "459",
                        "total_cost" : "59211",
                        "delay" : "1h00",
                        "best": "False",
                        }
                    
        }
}
)

Reco23 = json.dumps({
"data": {
                "title": "Modifier parcours",
                "description" : "Rebroussement et détournement des trains par la ligne classique entre Angoulême et Poitiers . ",
                "use_case": "Railway",
                "agent_type": "AI",
                "kpis": {
                        "cost" : "73",
                        "nb_impacted_passengers" : "459",
                        "total_cost" : "33507",
                        "delay" : "1h00",
                        "best": "True",
                        }
                    
        }
}
)


Reco24 = json.dumps({
"data": {
                "title": "Supprimer",
                "description" : "Suppression des trains. Les clients sont invités à reporter leur voyage.",
                "use_case": "Railway",
                "agent_type": "AI",
                "kpis": {
                        "cost" : "221",
                        "nb_impacted_passengers" : "459",
                        "total_cost" : "101439",
                        "delay" : "1h00",
                        "best": "False",
                        }
                    
        }
}
)

# %%
Reco31 = json.dumps({
"data": {
                "title": "Attendre en gare de Bordeaux",
                "description" : "Retenir le train en gare jusqu' à la restitution des voies.",
                "use_case": "Railway",
                "agent_type": "AI",
                "kpis": {
                        "cost" : "94",
                        "nb_impacted_passengers" : "348",
                        "total_cost" : "32712",
                        "delay" : "00h30",
                        "best": "True",
                        }
                    
        }
}
)


Reco32 = json.dumps({
"data": {
                "title": "Retarder",
                "description" : "Retenir le train en pleine voie jusqu'à la restitution des voies. Mise en place de moyens pour la prise en charge des clients ",
                "use_case": "Railway",
                "agent_type": "AI",
                "kpis": {
                        "cost" : "94",
                        "nb_impacted_passengers" : "347",
                        "total_cost" : "32618",
                        "delay" : "00h53",
                        "best": "False",
                        }
                    
        }
}
)


Reco33 = json.dumps({
"data": {
                "title": "Détourner de Bordeaux à Angoulême ",
                "description" : "Rebroussement et détournement des trains par la ligne classique entre Angoulême et Poitiers . ",
                "use_case": "Railway",
                "agent_type": "AI",
                "kpis": {
                        "cost" : "95",
                        "nb_impacted_passengers" : "348",
                        "total_cost" : "33060",
                        "delay" : "1h24",
                        "best": "False",
                        }
                    
        }
}
)

Reco34 = json.dumps({
"data": {
                "title": "Supprimer",
                "description" : "Suppression des trains. Les clients sont invités à reporter leur voyage.",
                "use_case": "Railway",
                "agent_type": "AI",
                "kpis": {
                        "cost" : "257",
                        "nb_impacted_passengers" : "348",
                        "total_cost" : "89436",
                        "delay" : "00h40",
                        "best": "False",
                        }
                    
        }
}
)

# %%
test = 1

# %% [markdown]
# Attendre/ retenir en gare
# Retarder
# Détourner/Modifier
# Supprimer
